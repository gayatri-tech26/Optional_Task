# %% [markdown]
# <a href="https://colab.research.google.com/github/gayatri-tech26/Optional_Task/blob/main/Optional_Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4200f234-78dc-457a-92ec-d6a5ac371f01" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4200f234-78dc-457a-92ec-d6a5ac371f01">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
filepath = '/content/StudentsPerformance.csv'
df = pd.read_csv(filepath)

# %%
print("First 5 rows of DataSet:")
df.head()
# Out:
# First 5 rows of DataSet:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
print("Last 5 rows of DataSet:")
df.tail()
# Out:
# Last 5 rows of DataSet:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
print("Shape of the DataSet:")
df.shape
# Out:
# Shape of the DataSet:
# (1000, 8)

# %%
print("Number of rows and columns:")
df.info()
# Out:
# Number of rows and columns:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
print("Statastical Summary of Numerical columns:")
df.describe()
# Out:
# Statastical Summary of Numerical columns:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
print("Misssing Values:")
df.isnull().sum()
# Out:
# Misssing Values:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
print("Checking Duplicate Rows:")
df.duplicated().sum()
# Out:
# Checking Duplicate Rows:
# np.int64(0)

# %%
print("Number of Unique Values:")
df.nunique()
# Out:
# Number of Unique Values:
# gender                          2
# race/ethnicity                  5
# parental level of education     6
# lunch                           2
# test preparation course         2
# math score                     81
# reading score                  72
# writing score                  77
# dtype: int64

# %%
print("Correlation:")
df.corr(numeric_only=True)
# Out:
# Correlation:
#                math score  reading score  writing score
# math score       1.000000       0.817580       0.802642
# reading score    0.817580       1.000000       0.954598
# writing score    0.802642       0.954598       1.000000

# %%
print("Count of null values:")
df.count()
# Out:
# Count of null values:
# gender                         1000
# race/ethnicity                 1000
# parental level of education    1000
# lunch                          1000
# test preparation course        1000
# math score                     1000
# reading score                  1000
# writing score                  1000
# dtype: int64

# %%
print("Random Sample:")
df.sample(5)
# Out:
# Random Sample:
#      gender race/ethnicity parental level of education         lunch  \
# 778  female        group A                some college      standard
# 181  female        group C                some college  free/reduced
# 407  female        group B          associate's degree      standard
# 216  female        group E          associate's degree  free/reduced
# 162    male        group B             master's degree  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 778               completed          72             79             82
# 181                    none          46             64             66
# 407                    none          82             80             77
# 216               completed          83             86             88
# 162                    none          49             53             52

# %%
print("Histograms:")
df.hist(figsize=(10,8))
plt.show()
# Out:
# Histograms:

# %%
print("Count plot:")
sns.countplot(x="gender",data=df)
# Out:
# Count plot:
# <Axes: xlabel='gender', ylabel='count'>

# %%
sns.countplot(x=df["gender"],hue=df["race/ethnicity"])
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
print("HeatMap:")
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# HeatMap:
# <Axes: >
